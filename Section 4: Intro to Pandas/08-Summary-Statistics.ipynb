# %%
import numpy as np

from pandas import Series, DataFrame

import pandas as pd

# %%
arr = np.array([[1,2, np.nan], [np.nan, 3, 4]])

# %%
dframe1 = DataFrame(arr, index=['A', 'B'], columns=['One', 'Two', 'Three'])

dframe1
# Out:
#    One  Two  Three
# A  1.0  2.0    NaN
# B  NaN  3.0    4.0

# %%
dframe1.sum() # sum column
# Out:
# One      1.0
# Two      5.0
# Three    4.0
# dtype: float64

# %%
dframe1.sum(axis=1) # sum row
# Out:
# A    3.0
# B    7.0
# dtype: float64

# %%
dframe1.min()
# Out:
# One      1.0
# Two      2.0
# Three    4.0
# dtype: float64

# %%
dframe1
# Out:
#    One  Two  Three
# A  1.0  2.0    NaN
# B  NaN  3.0    4.0

# %%
dframe1.idxmin()
# Out:
# One      A
# Two      A
# Three    B
# dtype: object

# %%
dframe1.cumsum() # sum columns progresively
# Out:
#    One  Two  Three
# A  1.0  2.0    NaN
# B  NaN  5.0    4.0

# %%
dframe1.describe()
# Out:
#        One       Two  Three
# count  1.0  2.000000    1.0
# mean   1.0  2.500000    4.0
# std    NaN  0.707107    NaN
# min    1.0  2.000000    4.0
# 25%    1.0  2.250000    4.0
# 50%    1.0  2.500000    4.0
# 75%    1.0  2.750000    4.0
# max    1.0  3.000000    4.0

# %%
from IPython.display import YouTubeVideo

# %%
YouTubeVideo('xGbpuFNR1ME')

# %%
YouTubeVideo('4EXNedimDMs')

# %%
import pandas_datareader.data as pdweb
import datetime

# %%
prices = pdweb.get_data_yahoo(['CVX', 'XOM', 'BP'], start = datetime.datetime(2010,1,1),
                                end=datetime.datetime(2013, 1, 1))['Adj Close']

prices.head()
# Out:
# Symbols           CVX        XOM         BP
# Date
# 2010-01-04  50.816982  45.575386  32.155743
# 2010-01-05  51.176937  45.753330  32.384068
# 2010-01-06  51.183357  46.148773  32.552601
# 2010-01-07  50.990532  46.003792  32.541725
# 2010-01-08  51.080528  45.819229  32.617828

# %%
volume = pdweb.get_data_yahoo(['CVX', 'XOM', 'BP'], start=datetime.datetime(2010,1,1),
                                end=datetime.datetime(2013,1,1))['Volume']

# %%
volume.head()
# Out:
# Symbols            CVX         XOM         BP
# Date
# 2010-01-04  10173800.0  27809100.0  3956100.0
# 2010-01-05  10593700.0  30174700.0  4109600.0
# 2010-01-06  11014600.0  35044700.0  6227900.0
# 2010-01-07   9626900.0  27192100.0  4431300.0
# 2010-01-08   5624300.0  24891800.0  3786100.0

# %%
rets = prices.pct_change()

# %%
# Correlation of the stocks
corr = rets.corr

# %%
# %matplotlib inline
prices.plot()
# Out:
# <AxesSubplot:xlabel='Date'>

# %%
import seaborn as sns
# from seaborn.regression import corrplot,symmatplot
import matplotlib.pyplot as plt

# %%
sns.heatmap(rets, annot=False)
# Out:
# <AxesSubplot:xlabel='Symbols', ylabel='Date'>

# %%
ser1 = Series(['w', 'w', 'x', 'y', 'z', 'w', 'x', 'y', 'x', 'a'])

ser1
# Out:
# 0    w
# 1    w
# 2    x
# 3    y
# 4    z
# 5    w
# 6    x
# 7    y
# 8    x
# 9    a
# dtype: object

# %%
ser1.unique()
# Out:
# array(['w', 'x', 'y', 'z', 'a'], dtype=object)

# %%
ser1.value_counts()
# Out:
# x    3
# w    3
# y    2
# z    1
# a    1
# dtype: int64
