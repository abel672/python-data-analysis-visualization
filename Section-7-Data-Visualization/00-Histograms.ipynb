# %%
# Standard
import numpy as np
import pandas as pd
from numpy.random import randn

# %%
# Stats
from scipy import stats

# %%
# Plotting
import matplotlib as mpl
import matplotlib.pyplot as plt
import seaborn as sns

# %%
# %matplotlib inline

# %%
url = 'https://en.wikipedia.org/wiki/Histogram'

# %%
dataset1 = randn(100)

# %%
plt.hist(dataset1)

# %%
dataset2 = randn(80)

plt.hist(dataset2, color='indianred')
# Out:
# (array([ 1.,  3.,  7.,  7., 19., 18.,  9., 11.,  3.,  2.]),
#  array([-2.715097  , -2.19245944, -1.66982187, -1.14718431, -0.62454674,
#         -0.10190918,  0.42072839,  0.94336595,  1.46600352,  1.98864108,
#          2.51127865]),
#  <BarContainer object of 10 artists>)

# %%
plt.hist(dataset1,density=True,color='indianred',alpha=0.5,bins=20)
plt.hist(dataset2,density=True,alpha=0.5,bins=20)
# Out:
# (array([0.0478343 , 0.        , 0.09566859, 0.0478343 , 0.19133718,
#         0.14350289, 0.23917148, 0.09566859, 0.38267437, 0.52617726,
#         0.62184585, 0.23917148, 0.14350289, 0.28700578, 0.33484007,
#         0.19133718, 0.09566859, 0.0478343 , 0.0478343 , 0.0478343 ]),
#  array([-2.715097  , -2.45377822, -2.19245944, -1.93114066, -1.66982187,
#         -1.40850309, -1.14718431, -0.88586553, -0.62454674, -0.36322796,
#         -0.10190918,  0.1594096 ,  0.42072839,  0.68204717,  0.94336595,
#          1.20468473,  1.46600352,  1.7273223 ,  1.98864108,  2.24995986,
#          2.51127865]),
#  <BarContainer object of 20 artists>)

# %%
data1 = randn(1000)
data2 = randn(1000)

# %%
sns.jointplot(data1, data2)
# Out:
# /Users/amescua/opt/anaconda3/lib/python3.7/site-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning

# %%
sns.jointplot(data1,data2,kind='hex')
# Out:
# /Users/amescua/opt/anaconda3/lib/python3.7/site-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning
